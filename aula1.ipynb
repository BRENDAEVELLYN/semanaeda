# %% [markdown]
# # Semana EDA (Exploratory Data Analysis)

# %% [markdown]
# # Análise Exploratória de Dados

# %% [markdown]
# Problema

# %% [markdown]
# - Uma escola necessita trabalhar com filmes em seu planejamento pedagógico.
# - Precisa visualizar as notas de diversos filmes em suas diversas categorias.
# - Os filmes devem atravessar gerações. A escola trabalha desde a creche até o nível superior.

# %% [markdown]
# ## Ambientação

# %% [markdown]
# - Usaremos a linguagem Python (multi, tip.din, ident, bibli, poo)
# - Antes de executar, crie uma venv.

# %%
# um alô mundo para não perder o costume
"""
Crie um "Hello EDA"

"""
mensagem = "Hello Semana EDA"
print(f"{mensagem}")
msg_input = input("digite a palavra da semana")
print(msg_input)
# Out:
# Hello Semana EDA
# animo

# %% [markdown]
# ## Competências

# %% [markdown]
# - Importar pandas
# - Ler dados csv
# - Organizar pastas no VS CODE
# - Renomear colunas
# - Contar dados
# - Melhorar visualização das informações
# - Criar gráficos pandas (plot), MatplotLib, Seaborn

# %% [markdown]
# ## Ferramentas e Recursos

# %% [markdown]
# - Jupyter (VS CODE, Anaconda, Jupyter, Google Colab, Azure, AWS)
# - Kaggle (Risco de Crédito): IA ML Superv. Regressão
# - TrendView (Opção de 100 mil)
# - Python - Lambda (Paradigma Funcional)
# - Bibliotecas (NumPy, Pandas, MatplotLib e Seaborn)
# - Gráficos (barras, pizza, dispersão, histograma, boxplot etc.)
# - YouTube (População, Amostra, Frequencia, Mediana, Quartis)
# - Estatística Descritiva (Frequencias e medidas)

# %% [markdown]
# ## Tipos de Variáveis

# %% [markdown]
# ### Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Pandas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### MySQL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Estatística Descritiva

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Importação do Pandas

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from pandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %% [markdown]
# ## importação do dataset

# %%
df = pd.read_csv('dataset/ratings.csv')

# %%
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
df['movieId']
# Out:
# 0              1
# 1              3
# 2              6
# 3             47
# 4             50
#            ...
# 100831    166534
# 100832    168248
# 100833    168250
# 100834    168252
# 100835    170875
# Name: movieId, Length: 100836, dtype: int64

# %%
df['rating']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: rating, Length: 100836, dtype: float64

# %% [markdown]
# ## Renomear as colunas em português

# %%
df.columns = ['usuario_id','filme_id','avaliacao','tempo']

# %%
df.columns
# Out:
# Index(['usuario_id', 'filme_id', 'avaliacao', 'tempo'], dtype='object')

# %% [markdown]
# mostrando uma coluna

# %%
df['avaliacao']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: avaliacao, Length: 100836, dtype: float64

# %% [markdown]
# mostrando coluna mais sintática

# %%
df.avaliacao
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: avaliacao, Length: 100836, dtype: float64

# %% [markdown]
# O chefe 360 solicitou a contagem de notas x

# %%
df.avaliacao.value_counts()
# Out:
# avaliacao
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %% [markdown]
# O lider 360° pediu a média de todas as notas.

# %%
#sem sentido
#df.mean()
# Out:
# usuario_id    3.261276e+02
# filme_id      1.943530e+04
# avaliacao     3.501557e+00
# tempo         1.205946e+09
# dtype: float64

# %%
df.avaliacao.mean()
# Out:
# np.float64(3.501556983616962)

# %% [markdown]
# # a média de tempo dos filmes avaliados em 4.0

# %%
df.head(25)
# Out:
#     usuario_id  filme_id  avaliacao      tempo
# 0            1         1        4.0  964982703
# 1            1         3        4.0  964981247
# 2            1         6        4.0  964982224
# 3            1        47        5.0  964983815
# 4            1        50        5.0  964982931
# 5            1        70        3.0  964982400
# 6            1       101        5.0  964980868
# 7            1       110        4.0  964982176
# 8            1       151        5.0  964984041
# 9            1       157        5.0  964984100
# 10           1       163        5.0  964983650
# 11           1       216        5.0  964981208
# 12           1       223        3.0  964980985
# 13           1       231        5.0  964981179
# 14           1       235        4.0  964980908
# 15           1       260        5.0  964981680
# 16           1       296        3.0  964982967
# 17           1       316        3.0  964982310
# 18           1       333        5.0  964981179
# 19           1       349        4.0  964982563
# 20           1       356        4.0  964980962
# 21           1       362        5.0  964982588
# 22           1       367        4.0  964981710
# 23           1       423        3.0  964982363
# 24           1       441        4.0  964980868

# %% [markdown]
# # Buscando valores únicos

# %%
df.avaliacao.unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %% [markdown]
# # Contando histórias com histogramas

# %%
! pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.53.1-cp312-cp312-win_amd64.whl.metadata (165 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from matplotlib) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
# Using cached contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.1-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
# Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.2 pillow-10.4.0 pyparsing-3.1.2

# %%
df.avaliacao.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.avaliacao.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: avaliacao, dtype: float64

# %% [markdown]
# # Media, Mediana (Q2 SEGUNDO QUARTIL), Soma

# %%
print(f"imprimindo a média: {df.avaliacao.mean()}")
# Out:
# imprimindo a média: 3.501556983616962

# %%
print(f"imprimindo o 2° quartil(mediana): {df.avaliacao.median()}")
# Out:
# imprimindo o 2° quartil(mediana): 3.5

# %%
print(f"imprimindo a soma: {df.avaliacao.sum()}")
# Out:
# imprimindo a soma: 353083.0

# %% [markdown]
# ## BOXPLOT

# %%
df.avaliacao.plot(kind='box')
# Out:
# <Axes: >

# %%
! pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ead\desktop\semanaeda(brenda)\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns

# %%
notas = df.avaliacao

# %% [markdown]
# eixo y

# %%
sns.boxplot(notas)
# Out:
# <Axes: ylabel='avaliacao'>

# %% [markdown]
# eixo x

# %%
sns.boxplot(x= notas)
# Out:
# <Axes: xlabel='avaliacao'>

# %% [markdown]
# Conclusão:
#
# - Que tipos de informações podemos extrair?
# - Conseguimos descobrir a metade (mediana)
# - Conseguimos demonstrar usando gráficos (histogramas e boxplot)
# - Ler os dados e apresentar esses dados.

# %% [markdown]
# ## Ex.1 Ler o dataset movies.csv

# %%
df_filmes = pd.read_csv('dataset/movies.csv')

# %% [markdown]
# ## Ex2. Mostrar os 5 primeiros

# %%
df_filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ## Ex.3 Renomear as colunas para ['filme_id,'titulo','generos']

# %%
df_filmes.columns = ['filme_id','titulo','generos']

# %% [markdown]
# ## Ex.4 Mostrar os 5 primeiros com colunas renomeadas

# %%
df_filmes.head(5)
# Out:
#    filme_id                              titulo  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ## Desafio - mostrar as cinco primeiras avaliações apenas do Toy Story com as colunas renomeadas. (dica: use df.query())

# %%
df_filmes.query("filme_id == 1").head()
# Out:
#    filme_id            titulo                                      generos
# 0         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
